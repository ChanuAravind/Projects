# %% [markdown]
# The exploration should have a goal. As you explore the data, keep in mind that you want to answer which type of shows to produce and how to grow the business.
# Ensure each recommendation is backed by data. The company is looking for data-driven insights, not personal opinions or anecdotes.
# Assume that you are presenting your findings to business executives who have only a basic understanding of data science. Avoid unnecessary technical jargon.
# Start by exploring a few questions: What type of content is available in different countries?
# How has the number of movies released per year changed over the last 20-30 years?
# Comparison of tv shows vs. movies.
# What is the best time to launch a TV show?
# Analysis of actors/directors of different types of shows/movies.
# Does Netflix has more focus on TV Shows than movies in recent years
# Understanding what content is available in different countries
# Evaluation Criteria (100 Points):
#
# 1. Defining Problem Statement and Analysing basic metrics
#
# 2. Observations on the shape of data, data types of all the attributes, conversion of categorical attributes to 'category' (If required), missing value detection, statistical summary
#
# 3. Non-Graphical Analysis: Value counts and unique attributes
#
# 4. Visual Analysis - Univariate, Bivariate after pre-processing of the data
#
# Note: Pre-processing involves unnesting of the data in columns like Actor, Director, Country
#
# 4.1 For continuous variable(s): Distplot, countplot, histogram for univariate analysis
#
# 4.2 For categorical variable(s): Boxplot
#
# 4.3 For correlation: Heatmaps, Pairplots
#
# 5. Missing Value & Outlier check (Treatment optional)
#
# 6. Insights based on Non-Graphical and Visual Analysis
#
# 6.1 Comments on the range of attributes
#
# 6.2 Comments on the distribution of the variables and relationship between them
#
# 6.3 Comments for each univariate and bivariate plot
#
# 7. Business Insights  - Should include patterns observed in the data along with what you can infer from it
#
# 8. Recommendations  - Actionable items for business. No technical jargon. No complications. Simple action items that everyone can understand

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# # Observations on the shape of data, data types of all the attributes, conversion of categorical attributes to 'category' (If required), missing value detection, statistical summary (10 Points)

# %%
os.chdir('C:\\Users\Ashok kumar\Desktop\chanu\DSML_Course\Class Files')

### Read CSV

df = pd.read_csv('netflix.csv')

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
df.type.unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
# we can convert type into category value

# %%
df.loc[df.type == 'Movie', 'type'] = 1

# %%
df.loc[df.type == 'TV Show', 'type'] = 0

# %%
df['type'] = df['type'].astype('int32')

# %%
df.head()
# Out:
#   show_id  type                  title         director  \
# 0      s1     1   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2     0          Blood & Water              NaN
# 2      s3     0              Ganglands  Julien Leclercq
# 3      s4     0  Jailbirds New Orleans              NaN
# 4      s5     0           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
df.type.value_counts()
# Out:
# 1    6131
# 0    2676
# Name: type, dtype: int64

# %%
df.release_year.value_counts().reset_index().sort_values('index').head()
# Out:
#     index  release_year
# 70   1925             1
# 67   1942             2
# 58   1943             3
# 54   1944             3
# 53   1945             4

# %% [markdown]
# we can see that after 1925 there are no movies/tv shows released till 1942, so we can consider that 1925 as an outlier and take possible actions

# %%
df.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
# There are some durations present in rating,so checking if there are any null values in duration feature.

# %%
df.duration.isna().sum()
# there are 3 null values in duration.
# Out:
# 3

# %%
df.loc[df.duration.isna()]
# Out:
#      show_id  type                                 title    director  \
# 5541   s5542     1                       Louis C.K. 2017  Louis C.K.
# 5794   s5795     1                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814     1  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added  release_year  rating  \
# 5541  Louis C.K.  United States       April 4, 2017          2017  74 min
# 5794  Louis C.K.  United States  September 16, 2016          2010  84 min
# 5813  Louis C.K.  United States     August 15, 2016          2015  66 min
#
#      duration listed_in                                        description
# 5541      NaN    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794      NaN    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813      NaN    Movies  The comic puts his trademark hilarious/thought...

# %%
#lets replace fill the duration null values
df.loc[df.duration.isna(),'duration'] = df.loc[df.duration.isna(),'rating']

# %%
df.duration.isna().sum()
# Out:
# 0

# %%
df.loc[df.director == 'Louis C.K.']
#replaced the duration and there are no null values
# Out:
#      show_id  type                                 title    director  \
# 5541   s5542     1                       Louis C.K. 2017  Louis C.K.
# 5794   s5795     1                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814     1  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added  release_year  rating  \
# 5541  Louis C.K.  United States       April 4, 2017          2017  74 min
# 5794  Louis C.K.  United States  September 16, 2016          2010  84 min
# 5813  Louis C.K.  United States     August 15, 2016          2015  66 min
#
#      duration listed_in                                        description
# 5541   74 min    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794   84 min    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813   66 min    Movies  The comic puts his trademark hilarious/thought...

# %%
df['date_added'] = pd.to_datetime(df['date_added'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   int32
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int32(1), int64(1), object(9)
# memory usage: 791.4+ KB

# %%
df['year_added'] = df['date_added'].dt.year

# %%
# we can find the null values in the year_added, for now we will assume that they are released directly in netflix so release year
#and date added, year added are same
df.loc[df.year_added.isna()]
# Out:
#      show_id  type                                        title director  \
# 6066   s6067     0  A Young Doctor's Notebook and Other Stories      NaN
# 6174   s6175     0              Anthony Bourdain: Parts Unknown      NaN
# 6795   s6796     0                                      Frasier      NaN
# 6806   s6807     0                                      Friends      NaN
# 6901   s6902     0                              Gunslinger Girl      NaN
# 7196   s7197     0                                     Kikoriki      NaN
# 7254   s7255     0                          La Familia P. Luche      NaN
# 7406   s7407     0                                        Maron      NaN
# 7847   s7848     0                                 Red vs. Blue      NaN
# 8182   s8183     0                 The Adventures of Figaro Pho      NaN
#
#                                                    cast         country  \
# 6066  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...  United Kingdom
# 6174                                   Anthony Bourdain   United States
# 6795  Kelsey Grammer, Jane Leeves, David Hyde Pierce...   United States
# 6806  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...   United States
# 6901  Yuuka Nanri, Kanako Mitsuhashi, Eri Sendai, Am...           Japan
# 7196                                      Igor Dmitriev             NaN
# 7254  Eugenio Derbez, Consuelo Duval, Luis Manuel Áv...   United States
# 7406  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...   United States
# 7847  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...   United States
# 8182  Luke Jurevicius, Craig Behenna, Charlotte Haml...       Australia
#
#      date_added  release_year rating    duration  \
# 6066        NaT          2013  TV-MA   2 Seasons
# 6174        NaT          2018  TV-PG   5 Seasons
# 6795        NaT          2003  TV-PG  11 Seasons
# 6806        NaT          2003  TV-14  10 Seasons
# 6901        NaT          2008  TV-14   2 Seasons
# 7196        NaT          2010   TV-Y   2 Seasons
# 7254        NaT          2012  TV-14   3 Seasons
# 7406        NaT          2016  TV-MA   4 Seasons
# 7847        NaT          2015     NR  13 Seasons
# 8182        NaT          2015  TV-Y7   2 Seasons
#
#                                               listed_in  \
# 6066           British TV Shows, TV Comedies, TV Dramas
# 6174                                         Docuseries
# 6795                     Classic & Cult TV, TV Comedies
# 6806                     Classic & Cult TV, TV Comedies
# 6901                       Anime Series, Crime TV Shows
# 7196                                           Kids' TV
# 7254  International TV Shows, Spanish-Language TV Sh...
# 7406                                        TV Comedies
# 7847  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 8182                              Kids' TV, TV Comedies
#
#                                             description  year_added
# 6066  Set during the Russian Revolution, this comic ...         NaN
# 6174  This CNN original series has chef Anthony Bour...         NaN
# 6795  Frasier Crane is a snooty but lovable Seattle ...         NaN
# 6806  This hit sitcom follows the merry misadventure...         NaN
# 6901  On the surface, the Social Welfare Agency appe...         NaN
# 7196  A wacky rabbit and his gang of animal pals hav...         NaN
# 7254  This irreverent sitcom featues Ludovico, Feder...         NaN
# 7406  Marc Maron stars as Marc Maron, who interviews...         NaN
# 7847  This parody of first-person shooter games, mil...         NaN
# 8182  Imagine your worst fears, then multiply them: ...         NaN

# %%
df.loc[df.year_added.isna(),'year_added'] = df.loc[df.year_added.isna(),'release_year']

# %%
df.loc[df.date_added.isna()]
# Out:
#      show_id  type                                        title director  \
# 6066   s6067     0  A Young Doctor's Notebook and Other Stories      NaN
# 6174   s6175     0              Anthony Bourdain: Parts Unknown      NaN
# 6795   s6796     0                                      Frasier      NaN
# 6806   s6807     0                                      Friends      NaN
# 6901   s6902     0                              Gunslinger Girl      NaN
# 7196   s7197     0                                     Kikoriki      NaN
# 7254   s7255     0                          La Familia P. Luche      NaN
# 7406   s7407     0                                        Maron      NaN
# 7847   s7848     0                                 Red vs. Blue      NaN
# 8182   s8183     0                 The Adventures of Figaro Pho      NaN
#
#                                                    cast         country  \
# 6066  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...  United Kingdom
# 6174                                   Anthony Bourdain   United States
# 6795  Kelsey Grammer, Jane Leeves, David Hyde Pierce...   United States
# 6806  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...   United States
# 6901  Yuuka Nanri, Kanako Mitsuhashi, Eri Sendai, Am...           Japan
# 7196                                      Igor Dmitriev             NaN
# 7254  Eugenio Derbez, Consuelo Duval, Luis Manuel Áv...   United States
# 7406  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...   United States
# 7847  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...   United States
# 8182  Luke Jurevicius, Craig Behenna, Charlotte Haml...       Australia
#
#      date_added  release_year rating    duration  \
# 6066        NaT          2013  TV-MA   2 Seasons
# 6174        NaT          2018  TV-PG   5 Seasons
# 6795        NaT          2003  TV-PG  11 Seasons
# 6806        NaT          2003  TV-14  10 Seasons
# 6901        NaT          2008  TV-14   2 Seasons
# 7196        NaT          2010   TV-Y   2 Seasons
# 7254        NaT          2012  TV-14   3 Seasons
# 7406        NaT          2016  TV-MA   4 Seasons
# 7847        NaT          2015     NR  13 Seasons
# 8182        NaT          2015  TV-Y7   2 Seasons
#
#                                               listed_in  \
# 6066           British TV Shows, TV Comedies, TV Dramas
# 6174                                         Docuseries
# 6795                     Classic & Cult TV, TV Comedies
# 6806                     Classic & Cult TV, TV Comedies
# 6901                       Anime Series, Crime TV Shows
# 7196                                           Kids' TV
# 7254  International TV Shows, Spanish-Language TV Sh...
# 7406                                        TV Comedies
# 7847  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 8182                              Kids' TV, TV Comedies
#
#                                             description  year_added
# 6066  Set during the Russian Revolution, this comic ...      2013.0
# 6174  This CNN original series has chef Anthony Bour...      2018.0
# 6795  Frasier Crane is a snooty but lovable Seattle ...      2003.0
# 6806  This hit sitcom follows the merry misadventure...      2003.0
# 6901  On the surface, the Social Welfare Agency appe...      2008.0
# 7196  A wacky rabbit and his gang of animal pals hav...      2010.0
# 7254  This irreverent sitcom featues Ludovico, Feder...      2012.0
# 7406  Marc Maron stars as Marc Maron, who interviews...      2016.0
# 7847  This parody of first-person shooter games, mil...      2015.0
# 8182  Imagine your worst fears, then multiply them: ...      2015.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   int32
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
#  12  year_added    8807 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(1), object(9)
# memory usage: 860.2+ KB

# %%
df.loc[df.rating.isna()]
# Out:
#      show_id  type                                              title  \
# 5989   s5990     1  13TH: A Conversation with Oprah Winfrey & Ava ...
# 6827   s6828     0                  Gargantia on the Verdurous Planet
# 7312   s7313     0                                       Little Lunch
# 7537   s7538     1                               My Honor Was Loyalty
#
#              director                                               cast  \
# 5989              NaN                        Oprah Winfrey, Ava DuVernay
# 6827              NaN  Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, Ka...
# 7312              NaN  Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...
# 7537  Alessandro Pepe  Leone Frisa, Paolo Vaccarino, Francesco Miglio...
#
#         country date_added  release_year rating  duration  \
# 5989        NaN 2017-01-26          2017    NaN    37 min
# 6827      Japan 2016-12-01          2013    NaN  1 Season
# 7312  Australia 2018-02-01          2015    NaN  1 Season
# 7537      Italy 2017-03-01          2015    NaN   115 min
#
#                                  listed_in  \
# 5989                                Movies
# 6827  Anime Series, International TV Shows
# 7312                 Kids' TV, TV Comedies
# 7537                                Dramas
#
#                                             description  year_added
# 5989  Oprah Winfrey sits down with director Ava DuVe...      2017.0
# 6827  After falling through a wormhole, a space-dwel...      2016.0
# 7312  Adopting a child's perspective, this show take...      2018.0
# 7537  Amid the chaos and horror of World War II, a c...      2017.0

# %%
df['year_added'] = df['year_added'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   int32
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
#  12  year_added    8807 non-null   int32
# dtypes: datetime64[ns](1), int32(2), int64(1), object(9)
# memory usage: 825.8+ KB

# %%
df.year_added.value_counts().sort_values(ascending=False)
# Out:
# 2019    2016
# 2020    1879
# 2018    1650
# 2021    1498
# 2017    1188
# 2016     430
# 2015      84
# 2014      24
# 2011      13
# 2013      12
# 2012       4
# 2008       3
# 2009       2
# 2003       2
# 2010       2
# Name: year_added, dtype: int64

# %%
df.year_added.nunique()
# Out:
# 15

# %% [markdown]
# From above we can say that no content was upoloaded to Netflix during 2004-2007, so we can consider 2003 as an outlier

# %%
df.describe()
# Out:
#               type  release_year   year_added
# count  8807.000000   8807.000000  8807.000000
# mean      0.696151   2014.180198  2018.863291
# std       0.459944      8.819312     1.602696
# min       0.000000   1925.000000  2003.000000
# 25%       0.000000   2013.000000  2018.000000
# 50%       1.000000   2017.000000  2019.000000
# 75%       1.000000   2019.000000  2020.000000
# max       1.000000   2021.000000  2021.000000

# %% [markdown]
# ->From the above statistical analysis we can infer that there are total 8807 movies and TV shows combined in Netflix from the years 1925 to 2021. there are more number of movies when compared to TV shows.
# -> TV shows or movies are added into netflix 2 years after they are released.

# %% [markdown]
# # Non-Graphical Analysis: Value counts and unique attributes (10 Points)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   int32
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
#  12  year_added    8807 non-null   int32
# dtypes: datetime64[ns](1), int32(2), int64(1), object(9)
# memory usage: 825.8+ KB

# %%
# from type we can say that there are only two kinds of content is present in netflix : Movies(1) and TV Shows(0) and 
# #_of_Movies > #_of_TV_Shows
# both combined there are total 8807 shows in netflix

# %%
df.type.value_counts()
# Out:
# 1    6131
# 0    2676
# Name: type, dtype: int64

# %%
# Most number of movies added in the year 2019 when compared to all other years
df.year_added.value_counts().sort_values(ascending=False)
# Out:
# 2019    2016
# 2020    1879
# 2018    1650
# 2021    1498
# 2017    1188
# 2016     430
# 2015      84
# 2014      24
# 2011      13
# 2013      12
# 2012       4
# 2008       3
# 2009       2
# 2003       2
# 2010       2
# Name: year_added, dtype: int64

# %%
#from the above result we can say that netflix started adding movies/tv shows from the year 2003 and later that it didnt added
# any content till 2008
df.year_added.nunique()
# Out:
# 15

# %%
# Most number of movies released in the year of 2018
df.release_year.value_counts().sort_values(ascending=False)
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: release_year, Length: 74, dtype: int64

# %%
df.year_added.nunique()
# Out:
# 15

# %%
# we have converted the movie duration into only numerical value to generate some insights
df.loc[df.type == 1,'duration']=df.duration.apply(lambda x: str(x).split()[0])

# %%
df.head()
# Out:
#   show_id  type                  title         director  \
# 0      s1     1   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2     0          Blood & Water              NaN
# 2      s3     0              Ganglands  Julien Leclercq
# 3      s4     0  Jailbirds New Orleans              NaN
# 4      s5     0           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13         90
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  year_added
# 0  As her father nears the end of his life, filmm...        2021
# 1  After crossing paths at a party, a Cape Town t...        2021
# 2  To protect his family from a powerful drug lor...        2021
# 3  Feuds, flirtations and toilet talk go down amo...        2021
# 4  In a city of coaching centers known to train I...        2021

# %%
#
duration_df=df.loc[df.type==1,'duration'].astype('int32')

# %%
duration_df=duration_df.reset_index()

# %%
duration_df=duration_df.sort_values('duration')

# %%
sns.histplot(data = duration_df,x='duration')
# Out:
# <AxesSubplot:xlabel='duration', ylabel='Count'>

# %%
duration_df.duration.min()
# Out:
# 3

# %%
duration_df.duration.max()
# Out:
# 312

# %%
director_df = df['director'].apply(lambda x: str(x).split(',')).to_list()
director_df = pd.DataFrame(director_df,index = df['title'])
director_df=director_df.stack()
director_df = pd.DataFrame(director_df)
director_df.reset_index(inplace = True)
director_df = director_df[['title',0]]
director_df.columns=['title','director']
director_df['director'] = director_df['director'].apply(lambda x : x.strip())
director_df.head()
# Out:
#                    title         director
# 0   Dick Johnson Is Dead  Kirsten Johnson
# 1          Blood & Water              nan
# 2              Ganglands  Julien Leclercq
# 3  Jailbirds New Orleans              nan
# 4           Kota Factory              nan

# %%
cast_df = df['cast'].apply(lambda x: str(x).split(',')).to_list()
cast_df = pd.DataFrame(cast_df,index = df['title'])
cast_df=cast_df.stack()
cast_df = pd.DataFrame(cast_df)
cast_df.reset_index(inplace = True)
cast_df = cast_df[['title',0]]
cast_df.columns=['title','cast']
cast_df['cast'] = cast_df['cast'].apply(lambda x : x.strip())
cast_df.head()
# Out:
#                   title            cast
# 0  Dick Johnson Is Dead             nan
# 1         Blood & Water      Ama Qamata
# 2         Blood & Water     Khosi Ngema
# 3         Blood & Water   Gail Mabalane
# 4         Blood & Water  Thabang Molaba

# %%
country_df = df['country'].apply(lambda x: str(x).split(',')).to_list()
country_df = pd.DataFrame(country_df,index = df['title'])
country_df = country_df.stack()
country_df = pd.DataFrame(country_df)
country_df.reset_index(inplace = True)
country_df = country_df[['title',0]]
country_df.columns=['title','country']
country_df['country'] = country_df['country'].apply(lambda x : x.strip())
country_df.head()
# Out:
#                    title        country
# 0   Dick Johnson Is Dead  United States
# 1          Blood & Water   South Africa
# 2              Ganglands            nan
# 3  Jailbirds New Orleans            nan
# 4           Kota Factory          India

# %%
listed_in_df = df['listed_in'].apply(lambda x: str(x).split(',')).to_list()
listed_in_df = pd.DataFrame(listed_in_df,index = df['title'])
listed_in_df = listed_in_df.stack()
listed_in_df = pd.DataFrame(listed_in_df)
listed_in_df.reset_index(inplace = True)
listed_in_df = listed_in_df[['title',0]]
listed_in_df.columns=['title','listed_in']
listed_in_df['listed_in'] = listed_in_df['listed_in'].apply(lambda x : x.strip())
listed_in_df.head()
# Out:
#                   title               listed_in
# 0  Dick Johnson Is Dead           Documentaries
# 1         Blood & Water  International TV Shows
# 2         Blood & Water               TV Dramas
# 3         Blood & Water            TV Mysteries
# 4             Ganglands          Crime TV Shows

# %%
dir_cas_df = director_df.merge(cast_df,how='inner',left_on='title',right_on='title')
dir_cas_df
# Out:
#                       title         director                   cast
# 0      Dick Johnson Is Dead  Kirsten Johnson                    nan
# 1             Blood & Water              nan             Ama Qamata
# 2             Blood & Water              nan            Khosi Ngema
# 3             Blood & Water              nan          Gail Mabalane
# 4             Blood & Water              nan         Thabang Molaba
# ...                     ...              ...                    ...
# 70807                Zubaan      Mozez Singh       Manish Chaudhary
# 70808                Zubaan      Mozez Singh           Meghna Malik
# 70809                Zubaan      Mozez Singh          Malkeet Rauni
# 70810                Zubaan      Mozez Singh         Anita Shabdish
# 70811                Zubaan      Mozez Singh  Chittaranjan Tripathy
#
# [70812 rows x 3 columns]

# %%
dir_cas_cou_df = dir_cas_df.merge(country_df,how='inner',left_on='title',right_on='title')
dir_cas_cou_df
# Out:
#                       title         director                   cast  \
# 0      Dick Johnson Is Dead  Kirsten Johnson                    nan
# 1             Blood & Water              nan             Ama Qamata
# 2             Blood & Water              nan            Khosi Ngema
# 3             Blood & Water              nan          Gail Mabalane
# 4             Blood & Water              nan         Thabang Molaba
# ...                     ...              ...                    ...
# 89410                Zubaan      Mozez Singh       Manish Chaudhary
# 89411                Zubaan      Mozez Singh           Meghna Malik
# 89412                Zubaan      Mozez Singh          Malkeet Rauni
# 89413                Zubaan      Mozez Singh         Anita Shabdish
# 89414                Zubaan      Mozez Singh  Chittaranjan Tripathy
#
#              country
# 0      United States
# 1       South Africa
# 2       South Africa
# 3       South Africa
# 4       South Africa
# ...              ...
# 89410          India
# 89411          India
# 89412          India
# 89413          India
# 89414          India
#
# [89415 rows x 4 columns]

# %%
dir_cas_cou_lis_df = dir_cas_cou_df.merge(listed_in_df,how='inner',left_on='title',right_on='title')
dir_cas_cou_lis_df
# Out:
#                        title         director                   cast  \
# 0       Dick Johnson Is Dead  Kirsten Johnson                    nan
# 1              Blood & Water              nan             Ama Qamata
# 2              Blood & Water              nan             Ama Qamata
# 3              Blood & Water              nan             Ama Qamata
# 4              Blood & Water              nan            Khosi Ngema
# ...                      ...              ...                    ...
# 202060                Zubaan      Mozez Singh         Anita Shabdish
# 202061                Zubaan      Mozez Singh         Anita Shabdish
# 202062                Zubaan      Mozez Singh  Chittaranjan Tripathy
# 202063                Zubaan      Mozez Singh  Chittaranjan Tripathy
# 202064                Zubaan      Mozez Singh  Chittaranjan Tripathy
#
#               country               listed_in
# 0       United States           Documentaries
# 1        South Africa  International TV Shows
# 2        South Africa               TV Dramas
# 3        South Africa            TV Mysteries
# 4        South Africa  International TV Shows
# ...               ...                     ...
# 202060          India    International Movies
# 202061          India        Music & Musicals
# 202062          India                  Dramas
# 202063          India    International Movies
# 202064          India        Music & Musicals
#
# [202065 rows x 5 columns]

# %%
trimmed_df = df.drop(['director','cast','country','listed_in'],axis = 1)
trimmed_df
# Out:
#      show_id  type                  title date_added  release_year rating  \
# 0         s1     1   Dick Johnson Is Dead 2021-09-25          2020  PG-13
# 1         s2     0          Blood & Water 2021-09-24          2021  TV-MA
# 2         s3     0              Ganglands 2021-09-24          2021  TV-MA
# 3         s4     0  Jailbirds New Orleans 2021-09-24          2021  TV-MA
# 4         s5     0           Kota Factory 2021-09-24          2021  TV-MA
# ...      ...   ...                    ...        ...           ...    ...
# 8802   s8803     1                 Zodiac 2019-11-20          2007      R
# 8803   s8804     0            Zombie Dumb 2019-07-01          2018  TV-Y7
# 8804   s8805     1             Zombieland 2019-11-01          2009      R
# 8805   s8806     1                   Zoom 2020-01-11          2006     PG
# 8806   s8807     1                 Zubaan 2019-03-02          2015  TV-14
#
#        duration                                        description  year_added
# 0            90  As her father nears the end of his life, filmm...        2021
# 1     2 Seasons  After crossing paths at a party, a Cape Town t...        2021
# 2      1 Season  To protect his family from a powerful drug lor...        2021
# 3      1 Season  Feuds, flirtations and toilet talk go down amo...        2021
# 4     2 Seasons  In a city of coaching centers known to train I...        2021
# ...         ...                                                ...         ...
# 8802        158  A political cartoonist, a crime reporter and a...        2019
# 8803  2 Seasons  While living alone in a spooky town, a young g...        2019
# 8804         88  Looking to survive in a world taken over by zo...        2019
# 8805         88  Dragged from civilian life, a former superhero...        2020
# 8806        111  A scrappy but poor boy worms his way into a ty...        2019
#
# [8807 rows x 9 columns]

# %%
new_df = trimmed_df.merge(dir_cas_cou_lis_df,how='inner',left_on='title',right_on='title')
new_df.head()
# Out:
#   show_id  type                 title date_added  release_year rating  \
# 0      s1     1  Dick Johnson Is Dead 2021-09-25          2020  PG-13
# 1      s2     0         Blood & Water 2021-09-24          2021  TV-MA
# 2      s2     0         Blood & Water 2021-09-24          2021  TV-MA
# 3      s2     0         Blood & Water 2021-09-24          2021  TV-MA
# 4      s2     0         Blood & Water 2021-09-24          2021  TV-MA
#
#     duration                                        description  year_added  \
# 0         90  As her father nears the end of his life, filmm...        2021
# 1  2 Seasons  After crossing paths at a party, a Cape Town t...        2021
# 2  2 Seasons  After crossing paths at a party, a Cape Town t...        2021
# 3  2 Seasons  After crossing paths at a party, a Cape Town t...        2021
# 4  2 Seasons  After crossing paths at a party, a Cape Town t...        2021
#
#           director         cast        country               listed_in
# 0  Kirsten Johnson          nan  United States           Documentaries
# 1              nan   Ama Qamata   South Africa  International TV Shows
# 2              nan   Ama Qamata   South Africa               TV Dramas
# 3              nan   Ama Qamata   South Africa            TV Mysteries
# 4              nan  Khosi Ngema   South Africa  International TV Shows

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 202065 entries, 0 to 202064
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   show_id       202065 non-null  object
#  1   type          202065 non-null  int32
#  2   title         202065 non-null  object
#  3   date_added    201907 non-null  datetime64[ns]
#  4   release_year  202065 non-null  int64
#  5   rating        201998 non-null  object
#  6   duration      202065 non-null  object
#  7   description   202065 non-null  object
#  8   year_added    202065 non-null  int32
#  9   director      202065 non-null  object
#  10  cast          202065 non-null  object
#  11  country       202065 non-null  object
#  12  listed_in     202065 non-null  object
# dtypes: datetime64[ns](1), int32(2), int64(1), object(9)
# memory usage: 20.0+ MB

# %%
new_df.shape
# Out:
# (202065, 13)

# %% [markdown]
# # Visual Analysis - Univariate, Bivariate after pre-processing of the data
#
# # Note: Pre-processing involves unnesting of the data in columns like Actor, Director, Country
#
# # 4.1 For continuous variable(s): Distplot, countplot, histogram for univariate analysis (10 Points)
#
# # 4.2 For categorical variable(s): Boxplot (10 Points)
#
# # 4.3 For correlation: Heatmaps, Pairplots (10 Points)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 202065 entries, 0 to 202064
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   show_id       202065 non-null  object
#  1   type          202065 non-null  int32
#  2   title         202065 non-null  object
#  3   date_added    201907 non-null  datetime64[ns]
#  4   release_year  202065 non-null  int64
#  5   rating        201998 non-null  object
#  6   duration      202065 non-null  object
#  7   description   202065 non-null  object
#  8   year_added    202065 non-null  int32
#  9   director      202065 non-null  object
#  10  cast          202065 non-null  object
#  11  country       202065 non-null  object
#  12  listed_in     202065 non-null  object
# dtypes: datetime64[ns](1), int32(2), int64(1), object(9)
# memory usage: 20.0+ MB

# %%
sns.histplot(new_df.year_added,bins =18)
# Out:
# <AxesSubplot:xlabel='year_added', ylabel='Count'>

# %%
actor_df = new_df.groupby('cast')['title'].nunique()

# %%
actor_df=actor_df.sort_values(ascending=False).reset_index()

# %%
actor_df.dropna(how='any',inplace=True)

# %%
actor_df
# Out:
#                          cast  title
# 0                         nan    825
# 1                 Anupam Kher     43
# 2              Shah Rukh Khan     35
# 3               Julie Tejwani     33
# 4            Naseeruddin Shah     32
# ...                       ...    ...
# 36435             Jamie Kenna      1
# 36436             Jamie Kaler      1
# 36437          Jamie Johnston      1
# 36438  Jamie Jacqueline Burns      1
# 36439            Ṣọpẹ́ Dìrísù      1
#
# [36440 rows x 2 columns]

# %%
actor_df=actor_df.drop(index=0)

# %%
# actor_df.loc[actor_df.title < 20,'cast'] = 'others'

# %%
actor_df.head()
# Out:
#                cast  title
# 1       Anupam Kher     43
# 2    Shah Rukh Khan     35
# 3     Julie Tejwani     33
# 4  Naseeruddin Shah     32
# 5  Takahiro Sakurai     32

# %% [markdown]
# We can say that 'Anupam Kher' is famous actor and people likes to watch his movies/tv shows

# %%
movie_df = new_df[new_df.type == 1]

# %%
movie_cast_count_df=movie_df.groupby('title')['cast'].nunique().sort_values(ascending = False).reset_index()

# %%
movie_cast_count_df.head()
# Out:
#                                                title  cast
# 0                                   Arthur Christmas    44
# 1  Michael Bolton's Big, Sexy Valentine's Day Spe...    41
# 2                          The Princess and the Frog    39
# 3                                           Movie 43    39
# 4                                        John Carter    38

# %%
movie_cast_count_df[movie_cast_count_df.cast > 2]
# Out:
#                                                   title  cast
# 0                                      Arthur Christmas    44
# 1     Michael Bolton's Big, Sexy Valentine's Day Spe...    41
# 2                             The Princess and the Frog    39
# 3                                              Movie 43    39
# 4                                           John Carter    38
# ...                                                 ...   ...
# 4895                           Krish Trish and Baltiboy     3
# 4896                   Benji's Very Own Christmas Story     3
# 4897     Krish Trish and Baltiboy: Best Friends Forever     3
# 4898          Krish Trish and Baltiboy: Comics of India     3
# 4899                                         Chopsticks     3
#
# [4900 rows x 2 columns]

# %%
director_df.groupby('director')['title'].nunique().sort_values()
# Out:
# director
# Jesse Adang         1
# Lisa Arnold         1
# Lisa Cortés         1
# Liu Bang-yao        1
# Liu Jiang           1
#                  ...
# Suhas Kadav        16
# Raúl Campos        19
# Jan Suter          21
# Rajiv Chilaka      22
# nan              2634
# Name: title, Length: 4994, dtype: int64

# %%
director_title_df
# Out:
#                      title
# director
# A. L. Vijay              2
# A. Raajdheep             1
# A. Salaam                1
# A.R. Murugadoss          2
# Aadish Keluskar          1
# ...                    ...
# Éric Warin               1
# Ísold Uggadóttir         1
# Óskar Thór Axelsson      1
# Ömer Faruk Sorak         3
# Şenol Sönmez             2
#
# [4994 rows x 1 columns]

# %%
# Out:
# 4978    2634
# 3749      22
# 1906      21
# 3800      19
# 4457      16
#         ...
# 635        1
# 2295       1
# 2296       1
# 2297       1
# 2957       1
# Name: title, Length: 4994, dtype: int64

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 202065 entries, 0 to 202064
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   show_id       202065 non-null  object
#  1   type          202065 non-null  int32
#  2   title         202065 non-null  object
#  3   date_added    201907 non-null  datetime64[ns]
#  4   release_year  202065 non-null  int64
#  5   rating        201998 non-null  object
#  6   duration      202065 non-null  object
#  7   description   202065 non-null  object
#  8   year_added    202065 non-null  int32
#  9   director      202065 non-null  object
#  10  cast          202065 non-null  object
#  11  country       202065 non-null  object
#  12  listed_in     202065 non-null  object
# dtypes: datetime64[ns](1), int32(2), int64(1), object(9)
# memory usage: 20.0+ MB

# %%
 new_df.groupby('title')['cast'].nunique().sort_values(ascending=False)
# Out:
# title
# Social Distance                    50
# Black Mirror                       50
# Creeped Out                        47
# COMEDIANS of the world             47
# Heartbreak High                    47
#                                    ..
# Little Singham in London            1
# Little Singham: Kaal Ki Tabaahi     1
# The Minimighty Kids                 1
# The Minimalists: Less Is Now        1
# Iliza Shlesinger: War Paint         1
# Name: cast, Length: 8807, dtype: int64

# %% [markdown]
# Social Distance and Black Mirror has more number of actors compared to all other tv shows/movies

# %%
new_df.listed_in.value_counts()
# Out:
# Dramas                          29806
# International Movies            28243
# Comedies                        20829
# International TV Shows          12845
# Action & Adventure              12216
# Independent Movies               9834
# Children & Family Movies         9771
# TV Dramas                        8942
# Thrillers                        7107
# Romantic Movies                  6412
# TV Comedies                      4963
# Crime TV Shows                   4733
# Horror Movies                    4571
# Kids' TV                         4568
# Sci-Fi & Fantasy                 4037
# Music & Musicals                 3077
# Romantic TV Shows                3049
# Documentaries                    2409
# Anime Series                     2313
# TV Action & Adventure            2288
# Spanish-Language TV Shows        2126
# British TV Shows                 1808
# Sports Movies                    1531
# Classic Movies                   1443
# TV Mysteries                     1281
# Korean TV Shows                  1122
# Cult Movies                      1077
# TV Sci-Fi & Fantasy              1045
# Anime Features                   1045
# TV Horror                         941
# Docuseries                        845
# LGBTQ Movies                      838
# TV Thrillers                      768
# Teen TV Shows                     742
# Reality TV                        735
# Faith & Spirituality              719
# Stand-Up Comedy                   540
# Movies                            412
# TV Shows                          337
# Classic & Cult TV                 272
# Stand-Up Comedy & Talk Shows      268
# Science & Nature TV               157
# Name: listed_in, dtype: int64

# %%
pd.DataFrame(new_df.groupby('title')['listed_in'].value_counts()).head(20)
# Out:
#                                                     listed_in
# title                         listed_in
# #Alive                        Horror Movies                 2
#                               International Movies          2
#                               Thrillers                     2
# #AnneFrank - Parallel Stories Documentaries                 4
#                               International Movies          4
# #FriendButMarried             Dramas                        8
#                               International Movies          8
#                               Romantic Movies               8
# #FriendButMarried 2           Dramas                        8
#                               International Movies          8
#                               Romantic Movies               8
# #Roxy                         Comedies                      8
#                               Romantic Movies               8
# #Rucker50                     Documentaries                 1
#                               Sports Movies                 1
# #Selfie                       Comedies                      8
#                               Dramas                        8
#                               International Movies          8
# #Selfie 69                    Comedies                     10
#                               Dramas                       10

# %%
sns.countplot(new_df.year_added)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year_added', ylabel='count'>

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 202065 entries, 0 to 202064
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   show_id       202065 non-null  object
#  1   type          202065 non-null  int32
#  2   title         202065 non-null  object
#  3   date_added    201907 non-null  datetime64[ns]
#  4   release_year  202065 non-null  int64
#  5   rating        201998 non-null  object
#  6   duration      202065 non-null  object
#  7   description   202065 non-null  object
#  8   year_added    202065 non-null  int32
#  9   director      202065 non-null  object
#  10  cast          202065 non-null  object
#  11  country       202065 non-null  object
#  12  listed_in     202065 non-null  object
# dtypes: datetime64[ns](1), int32(2), int64(1), object(9)
# memory usage: 20.0+ MB

# %%
sns.boxplot(new_df.listed_in=='Comedies',new_df.year_added)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='listed_in', ylabel='year_added'>

# %%
comedy = new_df[new_df.listed_in == 'Comedies']

# %%
comedy
# Out:
#        show_id  type         title date_added  release_year rating duration  \
# 331        s10     1  The Starling 2021-09-24          2021  PG-13      104
# 333        s10     1  The Starling 2021-09-24          2021  PG-13      104
# 335        s10     1  The Starling 2021-09-24          2021  PG-13      104
# 337        s10     1  The Starling 2021-09-24          2021  PG-13      104
# 339        s10     1  The Starling 2021-09-24          2021  PG-13      104
# ...        ...   ...           ...        ...           ...    ...      ...
# 202032   s8806     1          Zoom 2020-01-11          2006     PG       88
# 202034   s8806     1          Zoom 2020-01-11          2006     PG       88
# 202036   s8806     1          Zoom 2020-01-11          2006     PG       88
# 202038   s8806     1          Zoom 2020-01-11          2006     PG       88
# 202040   s8806     1          Zoom 2020-01-11          2006     PG       88
#
#                                               description  year_added  \
# 331     A woman adjusting to life after a loss contend...        2021
# 333     A woman adjusting to life after a loss contend...        2021
# 335     A woman adjusting to life after a loss contend...        2021
# 337     A woman adjusting to life after a loss contend...        2021
# 339     A woman adjusting to life after a loss contend...        2021
# ...                                                   ...         ...
# 202032  Dragged from civilian life, a former superhero...        2020
# 202034  Dragged from civilian life, a former superhero...        2020
# 202036  Dragged from civilian life, a former superhero...        2020
# 202038  Dragged from civilian life, a former superhero...        2020
# 202040  Dragged from civilian life, a former superhero...        2020
#
#               director              cast        country listed_in
# 331     Theodore Melfi  Melissa McCarthy  United States  Comedies
# 333     Theodore Melfi      Chris O'Dowd  United States  Comedies
# 335     Theodore Melfi       Kevin Kline  United States  Comedies
# 337     Theodore Melfi  Timothy Olyphant  United States  Comedies
# 339     Theodore Melfi      Daveed Diggs  United States  Comedies
# ...                ...               ...            ...       ...
# 202032    Peter Hewitt       Ryan Newman  United States  Comedies
# 202034    Peter Hewitt   Michael Cassidy  United States  Comedies
# 202036    Peter Hewitt   Spencer Breslin  United States  Comedies
# 202038    Peter Hewitt          Rip Torn  United States  Comedies
# 202040    Peter Hewitt      Kevin Zegers  United States  Comedies
#
# [20829 rows x 13 columns]

# %%
sns.boxplot(comedy.listed_in,new_df.year_added)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='listed_in', ylabel='year_added'>

# %%
comedy.groupby('title')['country'].nunique().sort_values(ascending=False)
# Out:
# title
# Arctic Dogs                              7
# The Death of Stalin                      5
# Houston, We Have a Problem!              5
# A Shaun the Sheep Movie: Farmageddon     5
# The Lobster                              5
#                                         ..
# House Party                              1
# House Arrest                             1
# Hotel Transylvania 3: Summer Vacation    1
# Hot Rod                                  1
# الف مبروك                                1
# Name: country, Length: 1674, dtype: int64

# %%
sns.boxplot(new_df.type,new_df.year_added)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='year_added'>

# %%
sns.pairplot(new_df)

# %%
country_df.country.value_counts()
# Out:
# United States     3690
# India             1046
# nan                831
# United Kingdom     806
# Canada             445
#                   ...
# Ecuador              1
# Armenia              1
# Mongolia             1
# Bahamas              1
# Montenegro           1
# Name: country, Length: 124, dtype: int64

# %%
listed_in_df.listed_in.value_counts()
# Out:
# International Movies            2752
# Dramas                          2427
# Comedies                        1674
# International TV Shows          1351
# Documentaries                    869
# Action & Adventure               859
# TV Dramas                        763
# Independent Movies               756
# Children & Family Movies         641
# Romantic Movies                  616
# TV Comedies                      581
# Thrillers                        577
# Crime TV Shows                   470
# Kids' TV                         451
# Docuseries                       395
# Music & Musicals                 375
# Romantic TV Shows                370
# Horror Movies                    357
# Stand-Up Comedy                  343
# Reality TV                       255
# British TV Shows                 253
# Sci-Fi & Fantasy                 243
# Sports Movies                    219
# Anime Series                     176
# Spanish-Language TV Shows        174
# TV Action & Adventure            168
# Korean TV Shows                  151
# Classic Movies                   116
# LGBTQ Movies                     102
# TV Mysteries                      98
# Science & Nature TV               92
# TV Sci-Fi & Fantasy               84
# TV Horror                         75
# Anime Features                    71
# Cult Movies                       71
# Teen TV Shows                     69
# Faith & Spirituality              65
# TV Thrillers                      57
# Movies                            57
# Stand-Up Comedy & Talk Shows      56
# Classic & Cult TV                 28
# TV Shows                          16
# Name: listed_in, dtype: int64

# %%
new_df.head()
# Out:
#   show_id  type                 title date_added  release_year rating  \
# 0      s1     1  Dick Johnson Is Dead 2021-09-25          2020  PG-13
# 1      s2     0         Blood & Water 2021-09-24          2021  TV-MA
# 2      s2     0         Blood & Water 2021-09-24          2021  TV-MA
# 3      s2     0         Blood & Water 2021-09-24          2021  TV-MA
# 4      s2     0         Blood & Water 2021-09-24          2021  TV-MA
#
#     duration                                        description  year_added  \
# 0         90  As her father nears the end of his life, filmm...        2021
# 1  2 Seasons  After crossing paths at a party, a Cape Town t...        2021
# 2  2 Seasons  After crossing paths at a party, a Cape Town t...        2021
# 3  2 Seasons  After crossing paths at a party, a Cape Town t...        2021
# 4  2 Seasons  After crossing paths at a party, a Cape Town t...        2021
#
#           director         cast        country               listed_in
# 0  Kirsten Johnson          nan  United States           Documentaries
# 1              nan   Ama Qamata   South Africa  International TV Shows
# 2              nan   Ama Qamata   South Africa               TV Dramas
# 3              nan   Ama Qamata   South Africa            TV Mysteries
# 4              nan  Khosi Ngema   South Africa  International TV Shows

# %%
new_df.loc[new_df.date_added.isna()]
# Out:
#        show_id  type                                        title date_added  \
# 136940   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136941   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136942   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136943   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136944   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# ...        ...   ...                                          ...        ...
# 186965   s8183     0                 The Adventures of Figaro Pho        NaT
# 186966   s8183     0                 The Adventures of Figaro Pho        NaT
# 186967   s8183     0                 The Adventures of Figaro Pho        NaT
# 186968   s8183     0                 The Adventures of Figaro Pho        NaT
# 186969   s8183     0                 The Adventures of Figaro Pho        NaT
#
#         release_year rating   duration  \
# 136940          2013  TV-MA  2 Seasons
# 136941          2013  TV-MA  2 Seasons
# 136942          2013  TV-MA  2 Seasons
# 136943          2013  TV-MA  2 Seasons
# 136944          2013  TV-MA  2 Seasons
# ...              ...    ...        ...
# 186965          2015  TV-Y7  2 Seasons
# 186966          2015  TV-Y7  2 Seasons
# 186967          2015  TV-Y7  2 Seasons
# 186968          2015  TV-Y7  2 Seasons
# 186969          2015  TV-Y7  2 Seasons
#
#                                               description  year_added  \
# 136940  Set during the Russian Revolution, this comic ...        2013
# 136941  Set during the Russian Revolution, this comic ...        2013
# 136942  Set during the Russian Revolution, this comic ...        2013
# 136943  Set during the Russian Revolution, this comic ...        2013
# 136944  Set during the Russian Revolution, this comic ...        2013
# ...                                                   ...         ...
# 186965  Imagine your worst fears, then multiply them: ...        2015
# 186966  Imagine your worst fears, then multiply them: ...        2015
# 186967  Imagine your worst fears, then multiply them: ...        2015
# 186968  Imagine your worst fears, then multiply them: ...        2015
# 186969  Imagine your worst fears, then multiply them: ...        2015
#
#        director                   cast         country         listed_in
# 136940      nan       Daniel Radcliffe  United Kingdom  British TV Shows
# 136941      nan       Daniel Radcliffe  United Kingdom       TV Comedies
# 136942      nan       Daniel Radcliffe  United Kingdom         TV Dramas
# 136943      nan               Jon Hamm  United Kingdom  British TV Shows
# 136944      nan               Jon Hamm  United Kingdom       TV Comedies
# ...         ...                    ...             ...               ...
# 186965      nan       Charlotte Hamlyn       Australia       TV Comedies
# 186966      nan  Stavroula Mountzouris       Australia          Kids' TV
# 186967      nan  Stavroula Mountzouris       Australia       TV Comedies
# 186968      nan        Aletheia Burney       Australia          Kids' TV
# 186969      nan        Aletheia Burney       Australia       TV Comedies
#
# [158 rows x 13 columns]

# %%
moviesreleased_df = new_df.groupby('year_added')['title'].count().reset_index()

# %%
sns.lineplot(x=moviesreleased_df.year_added,y=moviesreleased_df.title)
# Out:
# <AxesSubplot:xlabel='year_added', ylabel='title'>

# %%
new_df.head()
# Out:
#   show_id  type                 title date_added  release_year rating  \
# 0      s1     1  Dick Johnson Is Dead 2021-09-25          2020  PG-13
# 1      s2     0         Blood & Water 2021-09-24          2021  TV-MA
# 2      s2     0         Blood & Water 2021-09-24          2021  TV-MA
# 3      s2     0         Blood & Water 2021-09-24          2021  TV-MA
# 4      s2     0         Blood & Water 2021-09-24          2021  TV-MA
#
#     duration                                        description  year_added  \
# 0         90  As her father nears the end of his life, filmm...        2021
# 1  2 Seasons  After crossing paths at a party, a Cape Town t...        2021
# 2  2 Seasons  After crossing paths at a party, a Cape Town t...        2021
# 3  2 Seasons  After crossing paths at a party, a Cape Town t...        2021
# 4  2 Seasons  After crossing paths at a party, a Cape Town t...        2021
#
#           director         cast        country               listed_in
# 0  Kirsten Johnson          nan  United States           Documentaries
# 1              nan   Ama Qamata   South Africa  International TV Shows
# 2              nan   Ama Qamata   South Africa               TV Dramas
# 3              nan   Ama Qamata   South Africa            TV Mysteries
# 4              nan  Khosi Ngema   South Africa  International TV Shows

# %%
new_df['month'] = pd.to_datetime(new_df['date_added']).dt.month.astype('Int32')

# %%
new_df
# Out:
#        show_id  type                 title date_added  release_year rating  \
# 0           s1     1  Dick Johnson Is Dead 2021-09-25          2020  PG-13
# 1           s2     0         Blood & Water 2021-09-24          2021  TV-MA
# 2           s2     0         Blood & Water 2021-09-24          2021  TV-MA
# 3           s2     0         Blood & Water 2021-09-24          2021  TV-MA
# 4           s2     0         Blood & Water 2021-09-24          2021  TV-MA
# ...        ...   ...                   ...        ...           ...    ...
# 202060   s8807     1                Zubaan 2019-03-02          2015  TV-14
# 202061   s8807     1                Zubaan 2019-03-02          2015  TV-14
# 202062   s8807     1                Zubaan 2019-03-02          2015  TV-14
# 202063   s8807     1                Zubaan 2019-03-02          2015  TV-14
# 202064   s8807     1                Zubaan 2019-03-02          2015  TV-14
#
#          duration                                        description  \
# 0              90  As her father nears the end of his life, filmm...
# 1       2 Seasons  After crossing paths at a party, a Cape Town t...
# 2       2 Seasons  After crossing paths at a party, a Cape Town t...
# 3       2 Seasons  After crossing paths at a party, a Cape Town t...
# 4       2 Seasons  After crossing paths at a party, a Cape Town t...
# ...           ...                                                ...
# 202060        111  A scrappy but poor boy worms his way into a ty...
# 202061        111  A scrappy but poor boy worms his way into a ty...
# 202062        111  A scrappy but poor boy worms his way into a ty...
# 202063        111  A scrappy but poor boy worms his way into a ty...
# 202064        111  A scrappy but poor boy worms his way into a ty...
#
#         year_added         director                   cast        country  \
# 0             2021  Kirsten Johnson                    nan  United States
# 1             2021              nan             Ama Qamata   South Africa
# 2             2021              nan             Ama Qamata   South Africa
# 3             2021              nan             Ama Qamata   South Africa
# 4             2021              nan            Khosi Ngema   South Africa
# ...            ...              ...                    ...            ...
# 202060        2019      Mozez Singh         Anita Shabdish          India
# 202061        2019      Mozez Singh         Anita Shabdish          India
# 202062        2019      Mozez Singh  Chittaranjan Tripathy          India
# 202063        2019      Mozez Singh  Chittaranjan Tripathy          India
# 202064        2019      Mozez Singh  Chittaranjan Tripathy          India
#
#                      listed_in  month
# 0                Documentaries      9
# 1       International TV Shows      9
# 2                    TV Dramas      9
# 3                 TV Mysteries      9
# 4       International TV Shows      9
# ...                        ...    ...
# 202060    International Movies      3
# 202061        Music & Musicals      3
# 202062                  Dramas      3
# 202063    International Movies      3
# 202064        Music & Musicals      3
#
# [202065 rows x 14 columns]

# %%
new_df.loc[new_df.title == 'A Young Doctor\'s Notebook and Other Stories']
# Out:
#        show_id  type                                        title date_added  \
# 136940   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136941   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136942   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136943   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136944   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136945   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136946   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136947   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136948   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136949   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136950   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136951   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136952   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136953   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136954   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136955   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136956   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136957   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136958   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136959   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136960   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136961   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136962   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136963   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136964   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136965   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
# 136966   s6067     0  A Young Doctor's Notebook and Other Stories        NaT
#
#         release_year rating   duration  \
# 136940          2013  TV-MA  2 Seasons
# 136941          2013  TV-MA  2 Seasons
# 136942          2013  TV-MA  2 Seasons
# 136943          2013  TV-MA  2 Seasons
# 136944          2013  TV-MA  2 Seasons
# 136945          2013  TV-MA  2 Seasons
# 136946          2013  TV-MA  2 Seasons
# 136947          2013  TV-MA  2 Seasons
# 136948          2013  TV-MA  2 Seasons
# 136949          2013  TV-MA  2 Seasons
# 136950          2013  TV-MA  2 Seasons
# 136951          2013  TV-MA  2 Seasons
# 136952          2013  TV-MA  2 Seasons
# 136953          2013  TV-MA  2 Seasons
# 136954          2013  TV-MA  2 Seasons
# 136955          2013  TV-MA  2 Seasons
# 136956          2013  TV-MA  2 Seasons
# 136957          2013  TV-MA  2 Seasons
# 136958          2013  TV-MA  2 Seasons
# 136959          2013  TV-MA  2 Seasons
# 136960          2013  TV-MA  2 Seasons
# 136961          2013  TV-MA  2 Seasons
# 136962          2013  TV-MA  2 Seasons
# 136963          2013  TV-MA  2 Seasons
# 136964          2013  TV-MA  2 Seasons
# 136965          2013  TV-MA  2 Seasons
# 136966          2013  TV-MA  2 Seasons
#
#                                               description  year_added  \
# 136940  Set during the Russian Revolution, this comic ...        2013
# 136941  Set during the Russian Revolution, this comic ...        2013
# 136942  Set during the Russian Revolution, this comic ...        2013
# 136943  Set during the Russian Revolution, this comic ...        2013
# 136944  Set during the Russian Revolution, this comic ...        2013
# 136945  Set during the Russian Revolution, this comic ...        2013
# 136946  Set during the Russian Revolution, this comic ...        2013
# 136947  Set during the Russian Revolution, this comic ...        2013
# 136948  Set during the Russian Revolution, this comic ...        2013
# 136949  Set during the Russian Revolution, this comic ...        2013
# 136950  Set during the Russian Revolution, this comic ...        2013
# 136951  Set during the Russian Revolution, this comic ...        2013
# 136952  Set during the Russian Revolution, this comic ...        2013
# 136953  Set during the Russian Revolution, this comic ...        2013
# 136954  Set during the Russian Revolution, this comic ...        2013
# 136955  Set during the Russian Revolution, this comic ...        2013
# 136956  Set during the Russian Revolution, this comic ...        2013
# 136957  Set during the Russian Revolution, this comic ...        2013
# 136958  Set during the Russian Revolution, this comic ...        2013
# 136959  Set during the Russian Revolution, this comic ...        2013
# 136960  Set during the Russian Revolution, this comic ...        2013
# 136961  Set during the Russian Revolution, this comic ...        2013
# 136962  Set during the Russian Revolution, this comic ...        2013
# 136963  Set during the Russian Revolution, this comic ...        2013
# 136964  Set during the Russian Revolution, this comic ...        2013
# 136965  Set during the Russian Revolution, this comic ...        2013
# 136966  Set during the Russian Revolution, this comic ...        2013
#
#        director                cast         country         listed_in  month
# 136940      nan    Daniel Radcliffe  United Kingdom  British TV Shows   <NA>
# 136941      nan    Daniel Radcliffe  United Kingdom       TV Comedies   <NA>
# 136942      nan    Daniel Radcliffe  United Kingdom         TV Dramas   <NA>
# 136943      nan            Jon Hamm  United Kingdom  British TV Shows   <NA>
# 136944      nan            Jon Hamm  United Kingdom       TV Comedies   <NA>
# 136945      nan            Jon Hamm  United Kingdom         TV Dramas   <NA>
# 136946      nan         Adam Godley  United Kingdom  British TV Shows   <NA>
# 136947      nan         Adam Godley  United Kingdom       TV Comedies   <NA>
# 136948      nan         Adam Godley  United Kingdom         TV Dramas   <NA>
# 136949      nan  Christopher Godwin  United Kingdom  British TV Shows   <NA>
# 136950      nan  Christopher Godwin  United Kingdom       TV Comedies   <NA>
# 136951      nan  Christopher Godwin  United Kingdom         TV Dramas   <NA>
# 136952      nan     Rosie Cavaliero  United Kingdom  British TV Shows   <NA>
# 136953      nan     Rosie Cavaliero  United Kingdom       TV Comedies   <NA>
# 136954      nan     Rosie Cavaliero  United Kingdom         TV Dramas   <NA>
# 136955      nan    Vicki Pepperdine  United Kingdom  British TV Shows   <NA>
# 136956      nan    Vicki Pepperdine  United Kingdom       TV Comedies   <NA>
# 136957      nan    Vicki Pepperdine  United Kingdom         TV Dramas   <NA>
# 136958      nan     Margaret Clunie  United Kingdom  British TV Shows   <NA>
# 136959      nan     Margaret Clunie  United Kingdom       TV Comedies   <NA>
# 136960      nan     Margaret Clunie  United Kingdom         TV Dramas   <NA>
# 136961      nan           Tim Steed  United Kingdom  British TV Shows   <NA>
# 136962      nan           Tim Steed  United Kingdom       TV Comedies   <NA>
# 136963      nan           Tim Steed  United Kingdom         TV Dramas   <NA>
# 136964      nan           Shaun Pye  United Kingdom  British TV Shows   <NA>
# 136965      nan           Shaun Pye  United Kingdom       TV Comedies   <NA>
# 136966      nan           Shaun Pye  United Kingdom         TV Dramas   <NA>

# %%
new_df.month=new_df.month.fillna(0)

# %%
new_df.month.isna().sum()
# Out:
# 0

# %%
df['date_added'] = pd.to_datetime(df['date_added'])

# %%
df['month'] = pd.to_datetime(df['date_added']).dt.month

# %%
month_release=df.groupby('month')['year_added'].count().reset_index()

# %%
month_release.columns=['month','count']

# %%
sns.barplot(x="month", y="count", data=month_release)
# Out:
# <AxesSubplot:xlabel='month', ylabel='count'>

# %%
sns.histplot(df.type,bins=2)
# Out:
# <AxesSubplot:xlabel='type', ylabel='Count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   int32
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
#  12  year_added    8807 non-null   int32
#  13  month         8797 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int32(2), int64(1), object(9)
# memory usage: 894.6+ KB

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 202065 entries, 0 to 202064
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   show_id       202065 non-null  object
#  1   type          202065 non-null  int32
#  2   title         202065 non-null  object
#  3   date_added    201907 non-null  datetime64[ns]
#  4   release_year  202065 non-null  int64
#  5   rating        201998 non-null  object
#  6   duration      202065 non-null  object
#  7   description   202065 non-null  object
#  8   year_added    202065 non-null  int32
#  9   director      202065 non-null  object
#  10  cast          202065 non-null  object
#  11  country       202065 non-null  object
#  12  listed_in     202065 non-null  object
#  13  month         202065 non-null  Int32
# dtypes: Int32(1), datetime64[ns](1), int32(2), int64(1), object(9)
# memory usage: 29.1+ MB

# %%
sns.distplot(df.year_added)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='year_added', ylabel='Density'>

# %%
sns.countplot(df.year_added)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year_added', ylabel='count'>

# %%
sns.histplot(df.year_added)
# Out:
# <AxesSubplot:xlabel='year_added', ylabel='Count'>

# %%
sns.distplot(duration_df.duration)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='duration', ylabel='Density'>

# %%
sns.histplot(duration_df.duration)
# Out:
# <AxesSubplot:xlabel='duration', ylabel='Count'>

# %%
sns.boxplot(x=duration_df['duration'])
# Out:
# <AxesSubplot:xlabel='duration'>

# %%
sns.distplot(df.month)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='month', ylabel='Density'>

# %%
sns.boxplot(x=df["year_added"])
# Out:
# <AxesSubplot:xlabel='year_added'>

# %%
sns.boxplot(x=df["month"])
# Out:
# <AxesSubplot:xlabel='month'>

# %%
sns.pairplot(new_df)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 202065 entries, 0 to 202064
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   show_id       202065 non-null  object
#  1   type          202065 non-null  int32
#  2   title         202065 non-null  object
#  3   date_added    201907 non-null  datetime64[ns]
#  4   release_year  202065 non-null  int64
#  5   rating        201998 non-null  object
#  6   duration      202065 non-null  object
#  7   description   202065 non-null  object
#  8   year_added    202065 non-null  int32
#  9   director      202065 non-null  object
#  10  cast          202065 non-null  object
#  11  country       202065 non-null  object
#  12  listed_in     202065 non-null  object
#  13  month         202065 non-null  Int32
# dtypes: Int32(1), datetime64[ns](1), int32(2), int64(1), object(9)
# memory usage: 29.1+ MB

# %%
heat_df = new_df[['type','release_year','year_added']]

# %% [markdown]
# # Missing Value & Outlier check (Treatment optional) (10 Points)

# %%
df.release_year.value_counts().reset_index().sort_values('index').head()
# Out:
#     index  release_year
# 70   1925             1
# 67   1942             2
# 58   1943             3
# 54   1944             3
# 53   1945             4

# %% [markdown]
# we can see that after 1925 there are no movies/tv shows released till 1942, so we can consider that 1925 as an outlier and take possible actions

# %%
outlier_year = df.year_added.value_counts().reset_index()

# %%
outlier_year.head()
# Out:
#    index  year_added
# 0   2019        2016
# 1   2020        1879
# 2   2018        1650
# 3   2021        1498
# 4   2017        1188

# %%
outlier_year.sort_values('index')
# Out:
#     index  year_added
# 13   2003           2
# 11   2008           3
# 12   2009           2
# 14   2010           2
# 8    2011          13
# 10   2012           4
# 9    2013          12
# 7    2014          24
# 6    2015          84
# 5    2016         430
# 4    2017        1188
# 2    2018        1650
# 0    2019        2016
# 1    2020        1879
# 3    2021        1498

# %%
sns.boxplot(x=df["year_added"])
# Out:
# <AxesSubplot:xlabel='year_added'>

# %% [markdown]
# From above we can say that no content was upoloaded to Netflix during 2004-2007, so we can consider 2003 as an outlier
# and in above plot we can see outliers till 2015

# %%
sns.boxplot(x=duration_df['duration'])
# Out:
# <AxesSubplot:xlabel='duration'>

# %% [markdown]
# we can see there are many outliers in the duration of the movies

# %% [markdown]
# # 6. Insights based on Non-Graphical and Visual Analysis (10 Points)
#
# # 6.1 Comments on the range of attributes
# # 6.2 Comments on the distribution of the variables and relationship between them
# # 6.3 Comments for each univariate and bivariate plot

# %% [raw]
# -->Data present in the dataset are ranging from 2003 to 2021.
# -->Netflix consists of more movies than TV Shows.
# -->Most of them are produces in United States,India and United Kingdom.
# -->It is more likely to released in netflix after an year or two of the actual release date of the Movie/TV Show.
# -->Netflix Mostly contains content related to International Movies,Dramas,Comedies,International TV Shows.
# -->Netflix consists of movies/TV Shows from 1942 and a movie from 1925.
# -->There are 4900 movies with multi-starrer out of 6131 movies.
# --> Anupam Kher was the most successful actor.
# -->Rajiv Chilaka is the most successful director with 22 movies/TV Shows.
# -->Movie/ TV Show releases are evenly distributed all over the months and people likes to watch them in July mostly.
# -->There are more number of movies than the TV Shows in Netflix
# -->Most number of movies were added in the year of 2018-2019
# -->The mean duration of watchtime is 98 mins for movies.

# %% [markdown]
# # 7. Business Insights (10 Points) - Should include patterns observed in the data along with what you can infer from it

# %% [raw]
# --> The count of movies released in netflix are gradually decreasing from the year 2019
# --> Users are more intrested in movies rather than TV Shows
# --> Users prefer Multi-starrer rather than cast in it.
# --> Users intrested in the content from United States, India and United Kingdom.
# --> The most currated type of content are Dramas and Comedy.

# %% [markdown]
# # 8. Recommendations (10 Points) - Actionable items for business. No technical jargon. No complications. Simple action items that everyone can understand

# %% [raw]
# --> We can collaborate with some of the top actors and directors like Anupam Kher,Shah Rukh Khan.Julie Tejwani,
#     Naseeruddin Shah, Suhas Kadav,Raúl Campos,Jan Suter,Rajiv Chilaka and upload content from them as people were
#     intrested in them.
# --> we can also try to make some multi starrer movies with them in comedy or drama actions.
# --> The duration of the movie should be around 98 mins.
# --> Users are more intrested in the content from United States, India, and United Kingdom.
